# %% [markdown]
# # Research the Right Way Workshop
#
# A series of workshops about applied research techniques, with attention paid to replication and Open Science issues.
#
# - Code Like a Pro: Remote Python Development on KLC with VS Code, Github, & Copilot
#   - Date: May 2025
#   - Workshop Materials: [Jupyter Book](https://rs-kellogg.github.io/krs-KLCworkflow-cookbook/welcome.html)
#
# - Consumer Panel Data the Right Way
#   - Date: February 2025
#   - Workshop Materials: [GitHub repo](https://github.com/rs-kellogg/numerator-queries)
#
# - Prompt Engineering the Right Way
#   - Date: Octorber 2024
#   - Workshop Materials: [GitHub repo](https://github.com/rs-kellogg/prompting_right_way)
#
# - Open Source LLMs the Right Way
#   - Date: April 2024
#   - Workshop Materials: [Jupyter Book](https://rs-kellogg.github.io/krs-openllm-cookbook/welcome.html)
#
# - OpenAI the Right Way
#   - Date: November 2023
#   - Workshop Materials: [Jupyter Book](https://rs-kellogg.github.io/krs-llm-cookbook/welcome.html)
